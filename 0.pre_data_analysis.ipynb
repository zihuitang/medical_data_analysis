# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#0.load data
dt=pd.read_csv("D:\Data\python\data0.csv") 

#show the top 5 rows of data
dt.head()
# Out:
#    id  grp1  grp2       cov1      cov2  cov3  cov4        f1        f2  f3  \
# 0   1     0     2  10.588393  5.765045     0     2  8.883864  0.791934   1
# 1   2     1     0  10.095498  5.273806     0     1  8.497210  0.881411   1
# 2   3     0     2  10.221286  5.135972     1     2  8.175174  0.177713   0
# 3   4     1     3  10.884562  5.459708     0     0  8.421732  0.052869   1
# 4   5     0     2  10.707055  5.306728     0     1  8.714487  0.128239   1
#
#    f4      out1  out2  out3  out4  out4t
# 0   1  5.031413     0     1     1    201
# 1   0  5.737039     0     2     1    125
# 2   2  5.387061     1     2     0    152
# 3   3  5.031891     0     2     1    148
# 4   1  5.337904     1     1     0    127

# %%
#1. descripative statistics
dt.describe()
# Out:
#                id        grp1        grp2        cov1        cov2        cov3  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000    0.475000    1.375000   10.470692    5.454120    0.485000
# std     57.879185    0.500628    1.127266    0.295305    0.285599    0.501029
# min      1.000000    0.000000    0.000000   10.002984    5.005011    0.000000
# 25%     50.750000    0.000000    0.000000   10.188582    5.204004    0.000000
# 50%    100.500000    0.000000    1.000000   10.482112    5.430341    0.000000
# 75%    150.250000    1.000000    2.000000   10.723623    5.678592    1.000000
# max    200.000000    1.000000    3.000000   10.998129    5.998214    1.000000
#
#              cov4          f1          f2         f3          f4        out1  \
# count  200.000000  200.000000  200.000000  200.00000  200.000000  200.000000
# mean     1.050000    8.477591    0.474950    0.49500    1.360000    5.499473
# ...

# %%
#2 Figures

# %%
fig=plt.figure()
plt.plot(range(len(dt["f1"])),dt["f1"],label="f1 variable")
plt.legend(loc="upper left",frameon=True)

plt.title("distribution for variable")
plt.xlabel("id")
plt.ylabel("value")
plt.grid()
plt.show()

fig.savefig(r"D:\Data\python\test1.png",bbox_inches='tight')

# %%
plt.scatter(dt["cov2"],dt["f1"])

plt.title("distribution for variable")
plt.xlabel("id")
plt.ylabel("value")
plt.grid()
plt.show()
